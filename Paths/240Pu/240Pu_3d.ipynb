# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
LAP_nomass = np.loadtxt('../../Paths/240Pu/Eric_240Pu_LAP_Mass_False_path.txt',delimiter=',',skiprows=1)
MEP_nomass = np.loadtxt('../../Paths/240Pu/Eric_240Pu_MEP_Mass_False_path.txt',delimiter=',',skiprows=1)
LAP_mass = np.loadtxt('../../Paths/240Pu/Eric_240Pu_LAP_Mass_True_path.txt',delimiter=',',skiprows=1)
dp_nomass = np.loadtxt('../../Paths/240Pu/240Pu_const_path.txt',delimiter=',')
dp_mass = np.loadtxt('../../Paths/240Pu/240Pu_varied_path.txt',delimiter=',')
zero_col = np.zeros(len(dp_nomass))

dp_nomass = np.insert(dp_nomass,2,zero_col,axis=1)
zero_col = np.zeros(len(dp_mass))
dp_mass = np.insert(dp_mass,2,zero_col,axis=1)

# %%
# %matplotlib notebook

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(LAP_nomass[:,0], LAP_nomass[:,1], LAP_nomass[:,2], 'purple',label='LAP_NoMass')
ax.plot3D(MEP_nomass[:,0], MEP_nomass[:,1], MEP_nomass[:,2], 'red',label='MEP_NoMass')
ax.plot3D(dp_nomass[:,0], dp_nomass[:,1], dp_nomass[:,2], 'black',label='DP_NoMass')
ax.plot3D(LAP_mass[:,0], LAP_mass[:,1], LAP_mass[:,2], 'green',label='LAP_Mass')
#ax.plot3D(dp_mass[:,0], dp_mass[:,1], dp_mass[:,2], 'blue',label='DP_Mass')
ax.set_ylabel('$Q_{30}$',size=20)
ax.set_xlabel('$Q_{20}$',size=20)
ax.set_zlabel('$\lambda_{2}$',size=20)
ax.legend()
plt.plot
# Out:
# <img src="data:image/png;base64,..." width="640">
# <function matplotlib.pyplot.plot(*args, scalex=True, scaley=True, data=None, **kwargs)>
